# %%
#Users of the public API should cite the date that data were accessed or retrieved using the API. 
#Users must clearly state that “BLS.gov cannot vouch for the data or analyses derived from these data 
#after the data have been retrieved from BLS.gov.” import pandas as pdimport pandas as pd
import json
import requests

# %%
#headers = {'Content-type': 'application/json'}
data = json.dumps({https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?geoid=ND0000019981&minsaleamt=121465&maxsaleamt=465000&startsalesearchdate=2020-09-30&endsalesearchdate=2011-01-01})
response = requests.get(url).json()
#p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
# Out:
#   File "<ipython-input-2-895237e5ac4d>", line 2
#     data = json.dumps({https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?geoid=ND0000019981&minsaleamt=121465&maxsaleamt=465000&startsalesearchdate=2020-09-30&endsalesearchdate=2011-01-01})
#                               ^
# SyntaxError: invalid syntax

# %%
json_data = json.loads(p.text)
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 133,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'LNS14000000',
#     'data': [{'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'latest': 'true',
#       'value': '7.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '8.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '10.2',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '11.1',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '14.7',
#       'footnotes': [{}]},
#      {'year': '2020',
# ...

# %%
json_data['Results']['series'][0]['data']
# Out:
# [{'year': '2020',
#   'period': 'M09',
#   'periodName': 'September',
#   'latest': 'true',
#   'value': '7.9',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M08',
#   'periodName': 'August',
#   'value': '8.4',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M07',
#   'periodName': 'July',
#   'value': '10.2',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M06',
#   'periodName': 'June',
#   'value': '11.1',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M05',
#   'periodName': 'May',
#   'value': '13.3',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M04',
#   'periodName': 'April',
#   'value': '14.7',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M03',
#   'periodName': 'March',
#   'value': '4.4',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M02',
#   'periodName': 'February',
#   'value': '3.5',
#   'footnotes': [{}]},
#  {'year': '2020',
#   'period': 'M01',
#   'periodName': 'January',
# ...

# %%
len(json_data['Results']['series'][0]['data'])
# Out:
# 117

# %%
unempl_rates=json_data['Results']['series'][0]['data']

# %%
year=[]
month=[]
rate=[]
for i in range(117):
    year.append(unempl_rates[i]['year'])
    month.append(unempl_rates[i]['periodName'])
    rate.append(unempl_rates[i]['value'])

# %%
data_dict={"year":year,"month":month, "rate":rate}

# %%
unempl_data = pd.DataFrame(data_dict)
unempl_data
# Out:
#      year      month  rate
# 0    2020  September   7.9
# 1    2020     August   8.4
# 2    2020       July  10.2
# 3    2020       June  11.1
# 4    2020        May  13.3
# ..    ...        ...   ...
# 112  2011        May   9.0
# 113  2011      April   9.1
# 114  2011      March   9.0
# 115  2011   February   9.0
# 116  2011    January   9.1
#
# [117 rows x 3 columns]
